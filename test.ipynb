# %%
activities_json  ={
    "course_title": "IT031 LIVING IN THE IT ERA (Digital Technology)",
    "course_description": "This course covers the science, culture and ethics in information technology, its influence on modern living and human relationships, and uses for personal, professional, and social advancement.",
    "instructor_name": "Jun Albert Pardillo",
    "credit_units": "3",
    "total_hours": "54",
    "weekly_hours": "3",
    "clos": [
        "Understand the historical development of information technology and its global and national implications.",
        "Analyze the impact of information technology on society, culture, and human relationships.",
        "Evaluate the ethical considerations and challenges presented by the advancements in information technology.",
        "Assess the influence of information technology on professional, personal, and social advancement.",
        "Discuss the current trends and issues in information technology, particularly in the context of the Philippines."
    ],
    "topics": [
        {
            "topic": "Overview of Information Technology",
            "ilos": [
                "Describe the evolution and historical milestones of information technology from prehistoric times to the present.",
                "Explain the role of information technology in shaping global history and culture."
            ]
        },
        {
            "topic": "Information Technology and Society",
            "ilos": [
                "Analyze the effects of information technology innovations on firm performance and job creation.",
                "Discuss the impact of information technology on education and societal needs during the pandemic."
            ]
        },
        {
            "topic": "Information Technology in the Philippines",
            "ilos": [
                "Examine the employability and career trajectories of Information Technology Education graduates in the Philippines.",
                "Discuss the adoption and challenges of green IT practices among SMEs in the Philippines."
            ]
        },
        {
            "topic": "Ethical Issues in Information Technology",
            "ilos": [
                "Evaluate the ethical considerations and challenges posed by artificial intelligence and other disruptive technologies.",
                "Discuss the ethical, legal, and social implications of health information technology, particularly in the context of telehealth during pandemics."
            ]
        },
        {
            "topic": "Information Technology and Human Relationships",
            "ilos": [
                "Assess the influence of artificial intelligence and robotics on human resource management and customer relationships.",
                "Analyze the effects of the industry 4.0 revolution on human capital development and consumer behavior."
            ]
        }
    ],
    "references":[
        {
            "reference": "Campbell-Kelly, M., Aspray, W. F., Yost, J. R., & Tinn, H. (2023). Computer: A history of the information machine.",
            "link": "https://books.google.com/books?hl=en&lr=&id=G868EAAAQBAJ"
        },
        {
            "reference": "Chege, S. M., Wang, D., & Suntu, S. L. (2020). Impact of information technology innovation on firm performance in Kenya.",
            "link": "https://www.tandfonline.com/doi/abs/10.1080/02681102.2019.1573717"
        },
        {
            "reference": "Albina, A. C., & Sumagaysay, L. P. (2020). Employability tracer study of Information Technology Education graduates from a state university in the Philippines.",
            "link": "https://www.sciencedirect.com/science/article/pii/S2590291120300449"
        },
        {
            "reference": "Safdar, N. M., Banja, J. D., & Meltzer, C. C. (2020). Ethical considerations in artificial intelligence.",
            "link": "https://www.sciencedirect.com/science/article/pii/S0720048X19304188"
        },
        {
            "reference": "Vrontis, D., Christofi, M., Pereira, V., Tarba, S., & Thrassou, A. (2022). Artificial intelligence, robotics, advanced technologies and human resource management: a systematic review.",
            "link": "https://www.tandfonline.com/doi/abs/10.1080/09585192.2020.1871398"
        }
    ],
    "activities": [
        {
            "week": "Week 1",
            "topic": "Overview of Information Technology",
            "activity_description": "Introduction to the course and an overview of the syllabus, followed by a lecture on the prehistoric times to the early 20th century IT developments.",
            "expected_output": "Students will create a timeline of significant IT milestones.",
            "assessment_tools": "Timeline presentation and class participation"
        },
        {
            "week": "Week 2",
            "topic": "Overview of Information Technology",
            "activity_description": "Continuation of the historical overview focusing on post-World War II to the present IT developments.",
            "expected_output": "Students will write a short essay on the role of IT in a significant global event.",
            "assessment_tools": "Essay submission and discussion"
        },
        {
            "week": "Week 3",
            "topic": "Information Technology and Society",
            "activity_description": "Discussion on how IT innovations have impacted firm performance and job creation.",
            "expected_output": "Group presentation on case studies of IT impact on specific businesses.",
            "assessment_tools": "Presentation and peer evaluation"
        },
        {
            "week": "Week 4",
            "topic": "Information Technology and Society",
            "activity_description": "Exploration of IT's role in education and societal needs during the pandemic.",
            "expected_output": "Students will participate in a debate on the benefits and drawbacks of e-learning.",
            "assessment_tools": "Debate performance and reflection paper"
        },
        {
            "week": "Week 5",
            "topic": "Information Technology in the Philippines",
            "activity_description": "Investigation of the employability and career trajectories of IT graduates in the Philippines.",
            "expected_output": "Students will conduct interviews with IT professionals and present their findings.",
            "assessment_tools": "Interview report and presentation"
        },
        {
            "week": "Week 6",
            "topic": "Information Technology in the Philippines",
            "activity_description": "Examination of green IT practices among SMEs in the Philippines.",
            "expected_output": "Students will prepare a proposal for implementing green IT practices in a small business.",
            "assessment_tools": "Proposal document and class discussion"
        },
        {
            "week": "Week 7",
            "topic": "Ethical Issues in Information Technology",
            "activity_description": "Evaluation of ethical considerations in AI and disruptive technologies through a workshop.",
            "expected_output": "Students will develop ethical guidelines for AI use in a chosen industry.",
            "assessment_tools": "Workshop participation and guidelines document"
        },
        {
            "week": "Week 8",
            "topic": "Ethical Issues in Information Technology",
            "activity_description": "Discussion on the ethical, legal, and social implications of health IT.",
            "expected_output": "Students will create a case study analysis of telehealth services during pandemics.",
            "assessment_tools": "Case study analysis and class presentation"
        },
        {
            "week": "Week 9",
            "topic": "Information Technology and Human Relationships",
            "activity_description": "Assessment of AI's influence on HR management and customer relationships.",
            "expected_output": "Role-playing exercise to simulate AI integration in HR scenarios.",
            "assessment_tools": "Role-play demonstration and reflective journal"
        },
        {
            "week": "Week 10",
            "topic": "Information Technology and Human Relationships",
            "activity_description": "Analysis of Industry 4.0's effects on human capital and consumer behavior.",
            "expected_output": "Research paper on the implications of Industry 4.0 for a specific sector.",
            "assessment_tools": "Research paper and peer review"
        },
        {
            "week": "Week 11-18",
            "topic": "Capstone Project",
            "activity_description": "Students will work on a capstone project that encompasses all five topics, applying their knowledge to a real-world IT problem or scenario, with periodic check-ins and feedback sessions.",
            "expected_output": "A comprehensive report and presentation on the capstone project.",
            "assessment_tools": "Project report, presentation, and peer evaluation"
        }
    ]
}

# %%
from document_functions import *
# Out:
# 'test.docx'

# %% [markdown]
# # Steps Needed:
#
# ## Develop the needed functions
#     - Search Function: Get recent results from Google via SERP
#     - Scrape Function: Read online data from selected Google Searches
#     - Summarize Function: Extracts only the relevant information from a given online source
#     - File Retrieval (RAG): Allows users to add other course outlines as context for formatting and contents
#     - Document Functions: Functions for reading different types of documents (.txt, .docx, .pdf, etc.) as context as well as creating documents in a desired format
#
# ## Build Pipeline
# The process needs trial and error in terms of the right prompts and processes, but the overall simplified outline is as follows:
# 1) Educator inputs course details and (optionally) a sample course outline for reference
# 2) GPT Generates Queries to to look for references needed for the given course details
# 3) For each query, run an online search for resources and references
#     - ideally, these references should be from academic resources
# 4) Add the original request + the gathered resources as context for creating the final course outline/lesson plan
#     - Should have the following:
#         - Course Learning Outcomes (CLOs)
#         - Weekly Activities
#             - Each activity should have a week number, topic, activity description, expected output or assessment, and assessment tools
#         - References
# 5) Format the output with Document Functions to fit a pre-defined format

# %%
from search_functions import *
from gpt_functions import *
from app_functions import *

# %%
# Input sample course details
course_title = "Machine Learning"
course_description = "Machine Learning is a graduate-level course designed for Masters Degree CSIE students who are interested in exploring the field of artificial intelligence and its applications. This course provides an in-depth understanding of the fundamental concepts, algorithms, and techniques used in machine learning.\n\nThe course begins with an introduction to the basics of machine learning, including supervised and unsupervised learning, regression, classification, clustering, and dimensionality reduction. Students will learn how to use various machine learning algorithms such as decision trees, random forests, support vector machines, and neural networks to solve real-world problems.\n\nThe course also covers advanced topics such as deep learning, reinforcement learning, and natural language processing. Students will learn how to use deep learning techniques to build complex neural networks for image recognition, speech recognition, and natural language processing.\n\nThroughout the course, students will work on several hands-on projects and assignments to gain practical experience in implementing machine learning algorithms. They will also learn how to evaluate the performance of machine learning models and how to optimize them for better accuracy.\n\nBy the end of this course, students will have a solid understanding of the principles and techniques of machine learning and will be able to apply them to solve real-world problems. They will also be well-prepared to pursue further research in the field of artificial intelligence."
target_students = "4th Year Computer Science Students"
total_hours = 54
weekly_hours = 3
instructor_name = "Jun Albert Pardillo"

# convert course details into singular string
course_details = f"""
Course Name: {course_title}
Course Description: {course_description}
Target Students: {target_students}
Total Hours: {total_hours}
Class Hours per Week: {weekly_hours}
Instructor: {instructor_name}
"""

citation_style = "APA"
number_of_topics = 5

# %%
queries = generate_queries(course_details,5)
print(queries)
# Out:
# {
#     "queries": [
#         {
#             "topic": "Introduction to Machine Learning",
#             "query": "Introduction to machine learning textbooks"
#         },
#         {
#             "topic": "Supervised and Unsupervised Learning",
#             "query": "Supervised and unsupervised learning academic books"
#         },
#         {
#             "topic": "Machine Learning Algorithms",
#             "query": "Decision trees, random forests, support vector machines, and neural networks textbooks"
#         },
#         {
#             "topic": "Advanced Machine Learning Topics",
#             "query": "Deep learning, reinforcement learning, and natural language processing textbooks"
#         },
#         {
#             "topic": "Evaluating and Optimizing Machine Learning Models",
#             "query": "Evaluation and optimization of machine learning models academic books"
#         }
#     ]
# }

# %%
total_search_results = get_search_results(json.loads(queries))
print(total_search_results)
# Out:
# Topic: Introduction to Machine Learning
# Results:
#
#                 Title: Introduction to machine learning
#                 Link: https://books.google.com/books?hl=en&lr=&id=tZnSDwAAQBAJ&oi=fnd&pg=PR7&dq=Introduction+to+machine+learning+textbooks&ots=F4SW9WbpBe&sig=0mQG3DxbE1uUjCsJzw5aw1ht224
#                 Snippet: … program trained to translate, say, from English to French, sees more sample texts than any human translator. Machine learning is one of the hottest research areas in computer science. …
#                 Publication Summary: E Alpaydin - 2020 - books.google.com
#
#                 Title: Introduction to machine learning with applications in information security
#                 Link: https://www.taylorfrancis.com/books/mono/10.1201/9781003264873/introduction-machine-learning-applications-information-security-mark-stamp
#                 Snippet: … you find, and I will keep an updated errata list on the textbook website. … introduction to information security, your humble author is partial to the book [155]. Many of the machine learning …
#                 Publication Summary: M Stamp - 2022 - taylorfrancis.com
#
#                 Title: Machine learning fundamentals: A concise introduction
#                 Link: https://books.google.com/books?hl=en&lr=&id=L2dNEAAAQBAJ&oi=fnd&pg=PP1&dq=Introduction+to+machine+learning+textbooks&ots=UqzQ4-LkGj&sig=QjvVE42JfTVhqpE46noDYNWudbE
#                 Snippet: … This book is primarily written as a textbook for an introductory course on machine learning for senior undergraduate students in computer science and computer/ software/electrical …
#                 Publication Summary: H Jiang - 2021 - books.google.com
#
#                 Title: Machine learning foundations
#                 Link: https://link.springer.com/content/pdf/10.1007/978-3-030-65900-4.pdf
#                 Snippet: … knowledge about machine learning by exploring learning theories, … of machine learning algorithms: the supervised, the unsupervised, the reinforced, and the semi-supervised learning. …
#                 Publication Summary: T Jo - Machine Learning Foundations. Springer Nature …, 2021 - Springer
#
#                 Title: Learning in big data: Introduction to machine learning
#                 Link: https://www.sciencedirect.com/science/article/pii/B9780128191545000230
#                 Snippet: Abstract Machine learning (ML) is a subset of artificial intelligence that develops dynamic algorithms capable of data-driven decisions, in contrast to models that follow static …
#                 Publication Summary: K El Bouchefry, RS de Souza - Knowledge discovery in big data from …, 2020 - Elsevier
#                 Topic: Supervised and Unsupervised Learning
# Results:
#
#                 Title: A systematic review on supervised and unsupervised machine learning algorithms for data science
#                 Link: https://link.springer.com/chapter/10.1007/978-3-030-22475-2_1
#                 Snippet: … to analyze scholarly articles that were published between 2015 and 2018 addressing or implementing supervised and unsupervised machine learning … In most texts, it is considered a …
#                 Publication Summary: M Alloghani, D Al-Jumeily, J Mustafina… - … unsupervised learning …, 2020 - Springer
#
#                 Title: Supervised and unsupervised neural approaches to text readability
#                 Link: https://direct.mit.edu/coli/article-abstract/47/1/141/97334
#                 Snippet: … , which train machine learning models on texts with human-… readability levels on new unlabeled texts. Approaches that rely … a classification problem, several other supervised statistical …
#                 Publication Summary: M Martinc, S Pollak, M Robnik-Šikonja - Computational Linguistics, 2021 - direct.mit.edu
#
#                 Title: Machine learning foundations
#                 Link: https://link.springer.com/content/pdf/10.1007/978-3-030-65900-4.pdf
#                 Snippet: … In this book, we describe the machine learning algorithms with the … four kinds of supervised machine learning algorithms: K … this book is practical for people in both worlds: the academic …
#                 Publication Summary: T Jo - Machine Learning Foundations. Springer Nature …, 2021 - Springer
#
#                 Title: Introduction to machine learning
#                 Link: https://www.sciencedirect.com/science/article/pii/B9780128157398000018
#                 Snippet: … of the main approaches used in the machine learning literature: supervised learning, … this book, achieving high levels of generalizability is a key challenge in machine learning. …
#                 Publication Summary: S Vieira, WHL Pinaya, A Mechelli - Machine learning, 2020 - Elsevier
#
#                 Title: Deep learning: Foundations and concepts
#                 Link: https://link.springer.com/book/10.1007/978-3-031-45468-4?source=shoppingads&locale=en-jp
#                 Snippet: … This book offers a comprehensive introduction to the central … A full understanding of machine learning requires some … algorithms for supervised and unsupervised learning, modern deep …
#                 Publication Summary: CM Bishop, H Bishop - 2024 - Springer
#                 Topic: Machine Learning Algorithms
# Results:
#
#                 Title: Basic tenets of classification algorithms K-nearest-neighbor, support vector machine, random forest and neural network: a review
#                 Link: https://www.scirp.org/journal/paperinformation?paperid=104256
#                 Snippet: … as textbooks which employed four classification algorithms: K-Nearest-Neighbor (KNN), Support Vector Machines (SVM), Random Forest (… how the classification or regression trees are …
#                 Publication Summary: EY Boateng, J Otoo, DA Abaye - Journal of Data Analysis and Information …, 2020 - scirp.org
#
#                 Title: A comparative study of forecasting corporate credit ratings using neural networks, support vector machines, and decision trees
#                 Link: https://www.sciencedirect.com/science/article/pii/S1062940820301480
#                 Snippet: … , gaussian process classifier, random forest, gradient boosting machine) to predict Moody’s … random forest, artificial neural network and support vector machines where random forest …
#                 Publication Summary: P Golbayani, I Florescu, R Chatterjee - The North American Journal of …, 2020 - Elsevier
#
#                 Title: Comparison of random forest, support vector machines, and neural networks for post-disaster forest species mapping of the krkonoše/karkonosze transboundary …
#                 Link: https://www.mdpi.com/2072-4292/13/13/2581
#                 Snippet: … Random Forest being the best algorithm and Decision Trees … the Random Forest algorithm is the classification of six tree … in the accuracy of two classification methods: pixel and object…
#                 Publication Summary: B Zagajewski, M Kluczek, E Raczko, A Njegovec… - Remote Sensing, 2021 - mdpi.com
#
#                 Title: A comparative analysis of K-nearest neighbor, genetic, support vector machine, decision tree, and long short term memory algorithms in machine learning
#                 Link: https://www.sciencedirect.com/science/article/pii/S2772662222000261
#                 Snippet: … algorithms through his book Adaptation in Natural … neural networks, support vector machine algorithm with a radial basis function kernel, and General Linear Model (GLM) regression. …
#                 Publication Summary: M Bansal, A Goyal, A Choudhary - Decision Analytics Journal, 2022 - Elsevier
#
#                 Title: … performance of convolutional neural network, weighted and conventional support vector machine and random forest for classifying tree species using hyperspectral …
#                 Link: https://www.tandfonline.com/doi/abs/10.1080/15481603.2020.1712102
#                 Snippet: … the performance of two machine learning methods (support vector machine – SVM and random forest – RF) when employing different datasets at a pixel and individual tree crown (ITC) …
#                 Publication Summary: C Sothe, CM De Almeida, MB Schimalski… - GIScience & Remote …, 2020 - Taylor & Francis
#                 Topic: Advanced Machine Learning Topics
# Results:
#
#                 Title: Representation learning for natural language processing
#                 Link: https://library.oapen.org/handle/20.500.12657/76271
#                 Snippet: … list some books, reviews, and resources at the end of each chapter for readers to learn more … His insights to deep learning and representation learning, and sincere encouragements to …
#                 Publication Summary: Z Liu, Y Lin, M Sun - 2023 - library.oapen.org
#
#                 Title: An introduction to deep learning in natural language processing: Models, techniques, and tools
#                 Link: https://www.sciencedirect.com/science/article/pii/S0925231221010997
#                 Snippet: … (Generative Pre-Training) [43]. GPT uses 12-layer decoder only transformer structure with masked self-attention to train language model on 7000 unpublished books. Released in 2019, …
#                 Publication Summary: I Lauriola, A Lavelli, F Aiolli - Neurocomputing, 2022 - Elsevier
#
#                 Title: Neural network methods for natural language processing
#                 Link: https://books.google.com/books?hl=en&lr=&id=64hyEAAAQBAJ&oi=fnd&pg=PP1&dq=Deep+learning,+reinforcement+learning,+and+natural+language+processing+textbooks&ots=t8EcAJx7aC&sig=MSwmZLQVZcWFNLAENKJOlzyKm1o
#                 Snippet: … to speed with neural network techniques for natural language processing. While the primary audience of the book is graduate students in language processing and machine learning, I …
#                 Publication Summary: Y Goldberg - 2022 - books.google.com
#
#                 Title: Natural language processing advancements by deep learning: A survey
#                 Link: https://arxiv.org/abs/2003.01200
#                 Snippet: … The first subsection below explains methods used in the pre-deep learning period, as explained in reference NLP textbooks such as “Speech and Language Processing” [163]. The …
#                 Publication Summary: A Torfi, RA Shirvani, Y Keneshloo, N Tavaf… - arXiv preprint arXiv …, 2020 - arxiv.org
#
#                 Title: Practical natural language processing: a comprehensive guide to building real-world NLP systems
#                 Link: https://books.google.com/books?hl=en&lr=&id=hvrrDwAAQBAJ&oi=fnd&pg=PP1&dq=Deep+learning,+reinforcement+learning,+and+natural+language+processing+textbooks&ots=gsev9p6Uia&sig=tZFPUioV3H-3SKIQewACa6gqPEE
#                 Snippet: … and information from several books, research papers, software projects and numerous other resources on the inter‐net. We thank the NLP and Machine Learning community for all their …
#                 Publication Summary: S Vajjala, B Majumder, A Gupta, H Surana - 2020 - books.google.com
#                 Topic: Evaluating and Optimizing Machine Learning Models
# Results:
#
#                 Title: An efficient optimization approach for designing machine learning models based on genetic algorithm
#                 Link: https://link.springer.com/article/10.1007/s00521-020-05035-x
#                 Snippet: … ML models are evaluated by two performance evaluation … It can be noted that \(Str.\text {-}1\) has stationary trend and … Str.\text {-}6\) requires 75 (= 3800 function evaluations) generations …
#                 Publication Summary: KM Hamdia, X Zhuang, T Rabczuk - Neural Computing and Applications, 2021 - Springer
#
#                 Title: First-order and stochastic optimization methods for machine learning
#                 Link: https://link.springer.com/content/pdf/10.1007/978-3-030-39568-1.pdf
#                 Snippet: … to inspire the readers and also review some important optimization … The target audience of this book includes the graduate … The initial draft of this book has been used as the text for a …
#                 Publication Summary: G Lan - 2020 - Springer
#
#                 Title: Machine Learning with PyTorch and Scikit-Learn: Develop machine learning and deep learning models with Python
#                 Link: https://books.google.com/books?hl=en&lr=&id=SVxaEAAAQBAJ&oi=fnd&pg=PP1&dq=Evaluation+and+optimization+of+machine+learning+models+academic+books&ots=1duOyMxzjd&sig=21QZLijO9WVKWt2Sl1jqKr-oLDw
#                 Snippet: … edge of deep learning and have taken the fields of text understanding … optimize our machine learning model, while we keep the test dataset until the very end to evaluate the final model…
#                 Publication Summary: S Raschka, YH Liu, V Mirjalili, D Dzhulgakov - 2022 - books.google.com
#
#                 Title: Reinforcement Learning and Stochastic Optimization: A Unified Framework for Sequential Decisions: by Warren B. Powell (ed.), Wiley (2022). Hardback. ISBN …
#                 Link: https://www.tandfonline.com/doi/abs/10.1080/14697688.2022.2135456
#                 Snippet: … title of the book contains the words ‘reinforcement learning’ rather … in the communities of academics and practitioners alike, … book has an introductory chapter on reinforcement learning …
#                 Publication Summary: I Halperin - 2022 - Taylor & Francis
#
#                 Title: The Kaggle Book: Data analysis and machine learning for competitive data science
#                 Link: https://books.google.com/books?hl=en&lr=&id=GAVsEAAAQBAJ&oi=fnd&pg=PP1&dq=Evaluation+and+optimization+of+machine+learning+models+academic+books&ots=2tUJNvgwM1&sig=a0WCnSYCjI8CXMJz8iLvM73CMII
#                 Snippet: … book with other books on data science, machine learning, and … There are a few text conventions used throughout this book. … Amazon review page for this book and share your feedback. …
#                 Publication Summary: K Banachewicz, L Massaron - 2022 - books.google.com

# %%
learning_outcomes = generate_learning_outcomes(course_details=course_details, 
                                                       total_search_results=total_search_results, 
                                                       citation_style=citation_style,
                                                       number_of_topics=number_of_topics,
                                                       model='gpt-4o')
# Out:
# **Selected Academic References for the Machine Learning Course:**
#
# 1. **Introduction to Machine Learning**
#    - Title: "Introduction to machine learning"
#    - Link: [Introduction to machine learning](https://books.google.com/books?hl=en&lr=&id=tZnSDwAAQBAJ&oi=fnd&pg=PR7&dq=Introduction+to+machine+learning+textbooks&ots=F4SW9WbpBe&sig=0mQG3DxbE1uUjCsJzw5aw1ht224)
#    - Snippet: "… program trained to translate, say, from English to French, sees more sample texts than any human translator. Machine learning is one of the hottest research areas in computer science. …"
#    - Publication Summary: E Alpaydin - 2020 - books.google.com
#
# 2. **Machine Learning Fundamentals**
#    - Title: "Machine learning fundamentals: A concise introduction"
#    - Link: [Machine learning fundamentals: A concise introduction](https://books.google.com/books?hl=en&lr=&id=L2dNEAAAQBAJ&oi=fnd&pg=PP1&dq=Introduction+to+machine+learning+textbooks&ots=UqzQ4-LkGj&sig=QjvVE42JfTVhqpE46noDYNWudbE)
#    - Snippet: "… This book is primarily written as a textbook for an introductory course on machine learning for senior undergraduate students in computer science and computer/software/electrical …"
#    - Publication Summary: H Jiang - 2021 - books.google.com
#
# 3. **Machine Learning Foundations**
#    - Title: "Machine Learning Foundations"
#    - Link: [Machine Learning Foundations](https://link.springer.com/content/pdf/10.1007/978-3-030-65900-4.pdf)
#    - Snippet: "… knowledge about machine learning by exploring learning theories, … of machine learning algorithms: the supervised, the unsupervised, the reinforced, and the semi-supervised learning. …"
#    - Publication Summary: T Jo - Machine Learning Foundations. Springer Nature …, 2021 - Springer
#
# 4. **Neural Network Methods for Natural Language Processing**
#    - Title: "Neural network methods for natural language processing"
#    - Link: [Neural network methods for natural language processing](https://books.google.com/books?hl=en&lr=&id=64hyEAAAQBAJ&oi=fnd&pg=PP1&dq=Deep+learning,+reinforcement+learning,+and+natural+language+processing+textbooks&ots=t8EcAJx7aC&sig=MSwmZLQVZcWFNLAENKJOlzyKm1o)
#    - Snippet: "… to speed with neural network techniques for natural language processing. While the primary audience of the book is graduate students in language processing and machine learning, I …"
#    - Publication Summary: Y Goldberg - 2022 - books.google.com
#
# 5. **Machine Learning with PyTorch and Scikit-Learn**
#    - Title: "Machine Learning with PyTorch and Scikit-Learn: Develop machine learning and deep learning models with Python"
#    - Link: [Machine Learning with PyTorch and Scikit-Learn](https://books.google.com/books?hl=en&lr=&id=SVxaEAAAQBAJ&oi=fnd&pg=PP1&dq=Evaluation+and+optimization+of+machine+learning+models+academic+books&ots=1duOyMxzjd&sig=21QZLijO9WVKWt2Sl1jqKr-oLDw)
#    - Snippet: "… edge of deep learning and have taken the fields of text understanding … optimize our machine learning model, while we keep the test dataset until the very end to evaluate the final model…"
#    - Publication Summary: S Raschka, YH Liu, V Mirjalili, D Dzhulgakov - 2022 - books.google.com
#
# These references have been selected based on their relevance, recency, and academic nature, suitable for a graduate-level course in Machine Learning.

# %%
print(learning_outcomes)
# Out:
# ### Course Outline: Machine Learning
#
# #### Course Learning Outcomes (CLOs)
# By the end of this course, students will be able to:
# 1. **CLO1**: Describe the fundamental concepts and techniques of machine learning.
# 2. **CLO2**: Implement various machine learning algorithms to solve real-world problems.
# 3. **CLO3**: Evaluate the performance of machine learning models and optimize them for better accuracy.
# 4. **CLO4**: Apply deep learning techniques to build neural networks for tasks such as image recognition, speech recognition, and natural language processing.
# 5. **CLO5**: Explore and apply advanced topics in machine learning, including reinforcement learning and natural language processing.
#
# #### Topics/Modules and Intended Learning Outcomes (ILOs)
#
# **Topic 1: Introduction to Machine Learning**
# - **ILO 1.1**: Explain the basic concepts and history of machine learning. (Understand)
# - **ILO 1.2**: Differentiate between supervised, unsupervised, and reinforcement learning. (Understand)
# - **ILO 1.3**: Identify real-world applications of machine learning. (Remember)
#
# **Reference**:
# - Alpaydin, E. (2020). *Introduction to machine learning*. Retrieved from [Introduction to machine learning](https://books.google.com/books?hl=en&lr=&id=tZnSDwAAQBAJ&oi=fnd&pg=PR7&dq=Introduction+to+machine+learning+textbooks&ots=F4SW9WbpBe&sig=0mQG3DxbE1uUjCsJzw5aw1ht224)
#
# **Topic 2: Machine Learning Fundamentals**
# - **ILO 2.1**: Describe the basic principles of regression, classification, clustering, and dimensionality reduction. (Understand)
# - **ILO 2.2**: Implement basic algorithms for regression and classification. (Apply)
# - **ILO 2.3**: Compare the performance of different machine learning algorithms. (Analyze)
#
# **Reference**:
# - Jiang, H. (2021). *Machine learning fundamentals: A concise introduction*. Retrieved from [Machine learning fundamentals: A concise introduction](https://books.google.com/books?hl=en&lr=&id=L2dNEAAAQBAJ&oi=fnd&pg=PP1&dq=Introduction+to+machine+learning+textbooks&ots=UqzQ4-LkGj&sig=QjvVE42JfTVhqpE46noDYNWudbE)
#
# **Topic 3: Decision Trees and Random Forests**
# - **ILO 3.1**: Explain the concepts of decision trees and random forests. (Understand)
# - **ILO 3.2**: Implement decision trees and random forests for classification tasks. (Apply)
# - **ILO 3.3**: Evaluate the performance of decision trees and random forests. (Evaluate)
#
# **Reference**:
# - Jo, T. (2021). *Machine Learning Foundations*. Retrieved from [Machine Learning Foundations](https://link.springer.com/content/pdf/10.1007/978-3-030-65900-4.pdf)
#
# **Topic 4: Support Vector Machines**
# - **ILO 4.1**: Describe the theory behind support vector machines (SVMs). (Understand)
# - **ILO 4.2**: Implement SVMs for classification problems. (Apply)
# - **ILO 4.3**: Analyze the performance of SVMs on different datasets. (Analyze)
#
# **Reference**:
# - Jo, T. (2021). *Machine Learning Foundations*. Retrieved from [Machine Learning Foundations](https://link.springer.com/content/pdf/10.1007/978-3-030-65900-4.pdf)
#
# **Topic 5: Neural Networks and Deep Learning**
# - **ILO 5.1**: Explain the basic structure and functioning of neural networks. (Understand)
# - **ILO 5.2**: Implement simple neural networks using deep learning frameworks. (Apply)
# - **ILO 5.3**: Evaluate the performance of neural networks on image and speech recognition tasks. (Evaluate)
#
# **Reference**:
# - Raschka, S., Liu, Y. H., Mirjalili, V., & Dzhulgakov, D. (2022). *Machine Learning with PyTorch and Scikit-Learn: Develop machine learning and deep learning models with Python*. Retrieved from [Machine Learning with PyTorch and Scikit-Learn](https://books.google.com/books?hl=en&lr=&id=SVxaEAAAQBAJ&oi=fnd&pg=PP1&dq=Evaluation+and+optimization+of+machine+learning+models+academic+books&ots=1duOyMxzjd&sig=21QZLijO9WVKWt2Sl1jqKr-oLDw)
#
# **Topic 6: Natural Language Processing (NLP)**
# - **ILO 6.1**: Describe the key concepts of NLP and its applications. (Understand)
# - **ILO 6.2**: Implement neural network models for NLP tasks such as text classification and sentiment analysis. (Apply)
# - **ILO 6.3**: Evaluate the performance of NLP models on various datasets. (Evaluate)
#
# **Reference**:
# - Goldberg, Y. (2022). *Neural network methods for natural language processing*. Retrieved from [Neural network methods for natural language processing](https://books.google.com/books?hl=en&lr=&id=64hyEAAAQBAJ&oi=fnd&pg=PP1&dq=Deep+learning,+reinforcement+learning,+and+natural+language+processing+textbooks&ots=t8EcAJx7aC&sig=MSwmZLQVZcWFNLAENKJOlzyKm1o)
#
# **Topic 7: Reinforcement Learning**
# - **ILO 7.1**: Explain the principles of reinforcement learning. (Understand)
# - **ILO 7.2**: Implement basic reinforcement learning algorithms. (Apply)
# - **ILO 7.3**: Analyze the performance of reinforcement learning models in different environments. (Analyze)
#
# **Reference**:
# - Jo, T. (2021). *Machine Learning Foundations*. Retrieved from [Machine Learning Foundations](https://link.springer.com/content/pdf/10.1007/978-3-030-65900-4.pdf)
#
# **Topic 8: Evaluation and Optimization of Machine Learning Models**
# - **ILO 8.1**: Describe different methods for evaluating machine learning models. (Understand)
# - **ILO 8.2**: Implement techniques for optimizing model performance. (Apply)
# - **ILO 8.3**: Evaluate and compare the effectiveness of different optimization techniques. (Evaluate)
#
# **Reference**:
# - Raschka, S., Liu, Y. H., Mirjalili, V., & Dzhulgakov, D. (2022). *Machine Learning with PyTorch and Scikit-Learn: Develop machine learning and deep learning models with Python*. Retrieved from [Machine Learning with PyTorch and Scikit-Learn](https://books.google.com/books?hl=en&lr=&id=SVxaEAAAQBAJ&oi=fnd&pg=PP1&dq=Evaluation+and+optimization+of+machine+learning+models+academic+books&ots=1duOyMxzjd&sig=21QZLijO9WVKWt2Sl1jqKr-oLDw)
#
# ### Summary
# This course is designed to provide 4th year Computer Science students with a comprehensive understanding of machine learning, from fundamental concepts to advanced techniques. It emphasizes both conceptual understanding and practical implementation, preparing students to apply machine learning to real-world problems and to pursue further research in artificial intelligence.

# %%
course_outline = generate_course_outline(course_details=course_details, 
                                                learning_outcomes=learning_outcomes, 
                                                number_of_topics=number_of_topics, 
                                                total_hours=total_hours, 
                                                weekly_hours=weekly_hours,
                                                model='gpt-4o') 
course_outline_json = json.loads(course_outline)
course_outline_json
# Out:
# ### Course Outline: Machine Learning
#
# #### Course Learning Outcomes (CLOs)
# By the end of this course, students will be able to:
# 1. **CLO1**: Describe the fundamental concepts and techniques of machine learning.
# 2. **CLO2**: Implement various machine learning algorithms to solve real-world problems.
# 3. **CLO3**: Evaluate the performance of machine learning models and optimize them for better accuracy.
# 4. **CLO4**: Apply deep learning techniques to build neural networks for tasks such as image recognition, speech recognition, and natural language processing.
# 5. **CLO5**: Explore and apply advanced topics in machine learning, including reinforcement learning and natural language processing.
#
# ### Weekly Activities
#
# **Week 1: Introduction to Machine Learning**
# - **Topic**: Introduction to Machine Learning
# - **Activity Description**: Lecture on the basic concepts and history of machine learning, followed by a discussion on different types of learning (supervised, unsupervised, and reinforcement learning).
# - **Expected Output/Assessment**: Short essay on the history and types of machine learning.
# - **Assessment Tools**: Rubric for essay evaluation.
#
# **Week 2: Real-World Applications of Machine Learning**
# - **Topic**: Introduction to Machine Learning
# - **Activity Description**: Group discussion on various real-world applications of machine learning. Students will present case studies.
# - **Expected Output/Assessment**: Group presentation and report on real-world applications.
# - **Assessment Tools**: Presentation rubric and report assessment criteria.
#
# **Week 3: Fundamentals of Regression and Classification**
# - **Topic**: Machine Learning Fundamentals
# - **Activity Description**: Lecture on the principles of regression and classification, followed by hands-on implementation of basic algorithms using Python.
# - **Expected Output/Assessment**: Implementation of a simple regression and classification algorithm.
# - **Assessment Tools**: Code review and performance evaluation.
#
# **Week 4: Fundamentals of Clustering and Dimensionality Reduction**
# - **Topic**: Machine Learning Fundamentals
# - **Activity Description**: Lecture on clustering and dimensionality reduction techniques, followed by practical exercises.
# - **Expected Output/Assessment**: Implementation of clustering and dimensionality reduction algorithms.
# - **Assessment Tools**: Code review and performance evaluation.
#
# **Week 5: Decision Trees**
# - **Topic**: Decision Trees and Random Forests
# - **Activity Description**: Lecture on decision tree algorithms, followed by hands-on exercises to implement decision trees for classification tasks.
# - **Expected Output/Assessment**: Implementation of a decision tree algorithm.
# - **Assessment Tools**: Code review and performance evaluation.
#
# **Week 6: Random Forests**
# - **Topic**: Decision Trees and Random Forests
# - **Activity Description**: Lecture on random forests, followed by practical exercises.
# - **Expected Output/Assessment**: Implementation of a random forest algorithm.
# - **Assessment Tools**: Code review and performance evaluation.
#
# **Week 7: Performance Evaluation of Decision Trees and Random Forests**
# - **Topic**: Decision Trees and Random Forests
# - **Activity Description**: Lecture on performance evaluation techniques, followed by exercises to evaluate decision trees and random forests.
# - **Expected Output/Assessment**: Performance evaluation report.
# - **Assessment Tools**: Report assessment criteria.
#
# **Week 8: Introduction to Support Vector Machines (SVMs)**
# - **Topic**: Support Vector Machines
# - **Activity Description**: Lecture on the theory behind SVMs, followed by practical exercises to implement SVMs for classification tasks.
# - **Expected Output/Assessment**: Implementation of an SVM algorithm.
# - **Assessment Tools**: Code review and performance evaluation.
#
# **Week 9: Performance Analysis of SVMs**
# - **Topic**: Support Vector Machines
# - **Activity Description**: Lecture on performance analysis techniques, followed by exercises to analyze the performance of SVMs on different datasets.
# - **Expected Output/Assessment**: Performance analysis report.
# - **Assessment Tools**: Report assessment criteria.
#
# **Week 10: Introduction to Neural Networks**
# - **Topic**: Neural Networks and Deep Learning
# - **Activity Description**: Lecture on the basic structure and functioning of neural networks, followed by practical exercises.
# - **Expected Output/Assessment**: Implementation of a simple neural network.
# - **Assessment Tools**: Code review and performance evaluation.
#
# **Week 11: Deep Learning Frameworks**
# - **Topic**: Neural Networks and Deep Learning
# - **Activity Description**: Introduction to deep learning frameworks such as TensorFlow and PyTorch, followed by hands-on exercises.
# - **Expected Output/Assessment**: Implementation of a neural network using a deep learning framework.
# - **Assessment Tools**: Code review and performance evaluation.
#
# **Week 12: Advanced Neural Networks**
# - **Topic**: Neural Networks and Deep Learning
# - **Activity Description**: Lecture on advanced neural network architectures, followed by practical exercises.
# - **Expected Output/Assessment**: Implementation of an advanced neural network (e.g., CNN, RNN).
# - **Assessment Tools**: Code review and performance evaluation.
#
# **Week 13: Introduction to Natural Language Processing (NLP)**
# - **Topic**: Natural Language Processing (NLP)
# - **Activity Description**: Lecture on key concepts of NLP and its applications, followed by practical exercises.
# - **Expected Output/Assessment**: Implementation of a basic NLP task (e.g., text classification).
# - **Assessment Tools**: Code review and performance evaluation.
#
# **Week 14: Advanced NLP Techniques**
# - **Topic**: Natural Language Processing (NLP)
# - **Activity Description**: Lecture on advanced NLP techniques, followed by hands-on exercises.
# - **Expected Output/Assessment**: Implementation of an advanced NLP task (e.g., sentiment analysis).
# - **Assessment Tools**: Code review and performance evaluation.
#
# **Week 15: Introduction to Reinforcement Learning**
# - **Topic**: Reinforcement Learning
# - **Activity Description**: Lecture on the principles of reinforcement learning, followed by practical exercises.
# - **Expected Output/Assessment**: Implementation of a basic reinforcement learning algorithm.
# - **Assessment Tools**: Code review and performance evaluation.
#
# **Week 16: Advanced Reinforcement Learning**
# - **Topic**: Reinforcement Learning
# - **Activity Description**: Lecture on advanced reinforcement learning techniques, followed by hands-on exercises.
# - **Expected Output/Assessment**: Implementation of an advanced reinforcement learning algorithm.
# - **Assessment Tools**: Code review and performance evaluation.
#
# **Week 17: Evaluation and Optimization of Machine Learning Models**
# - **Topic**: Evaluation and Optimization of Machine Learning Models
# - **Activity Description**: Lecture on evaluation and optimization techniques, followed by practical exercises.
# - **Expected Output/Assessment**: Implementation of model evaluation and optimization techniques.
# - **Assessment Tools**: Code review and performance evaluation.
#
# **Week 18: Final Project Presentation**
# - **Topic**: Course Wrap-Up
# - **Activity Description**: Students will present their final projects, showcasing their ability to apply machine learning techniques to solve real-world problems.
# - **Expected Output/Assessment**: Final project presentation and report.
# - **Assessment Tools**: Presentation rubric and report assessment criteria.
#
# ### Summary
# This course is designed to provide 4th year Computer Science students with a comprehensive understanding of machine learning, from fundamental concepts to advanced techniques. It emphasizes both conceptual understanding and practical implementation, preparing students to apply machine learning to real-world problems and to pursue further research in artificial intelligence.
# {'course_title': 'Machine Learning',
#  'course_description': 'Machine Learning is a graduate-level course designed for Masters Degree CSIE students who are interested in exploring the field of artificial intelligence and its applications. This course provides an in-depth understanding of the fundamental concepts, algorithms, and techniques used in machine learning. The course begins with an introduction to the basics of machine learning, including supervised and unsupervised learning, regression, classification, clustering, and dimensionality reduction. Students will learn how to use various machine learning algorithms such as decision trees, random forests, support vector machines, and neural networks to solve real-world problems. The course also covers advanced topics such as deep learning, reinforcement learning, and natural language processing. Students will learn how to use deep learning techniques to build complex neural networks for image recognition, speech recognition, and natural language processing. Throughout the course, students will work on several hands-on projects and assignments to gain practical experience in implementing machine learning algorithms. They will also learn how to evaluate the performance of machine learning models and how to optimize them for better accuracy. By the end of this course, students will have a solid understanding of the principles and techniques of machine learning and will be able to apply them to solve real-world problems. They will also be well-prepared to pursue further research in the field of artificial intelligence.',
#  'instructor_name': 'Jun Albert Pardillo',
#  'credit_units': '3',
#  'total_hours': '54',
#  'weekly_hours': '3',
#  'clos': ['Describe the fundamental concepts and techniques of machine learning.',
#   'Implement various machine learning algorithms to solve real-world problems.',
#   'Evaluate the performance of machine learning models and optimize them for better accuracy.',
#   'Apply deep learning techniques to build neural networks for tasks such as image recognition, speech recognition, and natural language processing.',
#   'Explore and apply advanced topics in machine learning, including reinforcement learning and natural language processing.'],
#  'topics': [{'topic': 'Introduction to Machine Learning',
#    'ilos': ['Explain the basic concepts and history of machine learning. (Understand)',
#     'Differentiate between supervised, unsupervised, and reinforcement learning. (Understand)',
#     'Identify real-world applications of machine learning. (Remember)']},
#   {'topic': 'Machine Learning Fundamentals',
#    'ilos': ['Describe the basic principles of regression, classification, clustering, and dimensionality reduction. (Understand)',
#     'Implement basic algorithms for regression and classification. (Apply)',
#     'Compare the performance of different machine learning algorithms. (Analyze)']},
#   {'topic': 'Decision Trees and Random Forests',
#    'ilos': ['Explain the concepts of decision trees and random forests. (Understand)',
#     'Implement decision trees and random forests for classification tasks. (Apply)',
#     'Evaluate the performance of decision trees and random forests. (Evaluate)']},
#   {'topic': 'Support Vector Machines',
#    'ilos': ['Describe the theory behind support vector machines (SVMs). (Understand)',
#     'Implement SVMs for classification problems. (Apply)',
#     'Analyze the performance of SVMs on different datasets. (Analyze)']},
#   {'topic': 'Neural Networks and Deep Learning',
#    'ilos': ['Explain the basic structure and functioning of neural networks. (Understand)',
#     'Implement simple neural networks using deep learning frameworks. (Apply)',
#     'Evaluate the performance of neural networks on image and speech recognition tasks. (Evaluate)']},
#   {'topic': 'Natural Language Processing (NLP)',
#    'ilos': ['Describe the key concepts of NLP and its applications. (Understand)',
#     'Implement neural network models for NLP tasks such as text classification and sentiment analysis. (Apply)',
#     'Evaluate the performance of NLP models on various datasets. (Evaluate)']},
#   {'topic': 'Reinforcement Learning',
#    'ilos': ['Explain the principles of reinforcement learning. (Understand)',
#     'Implement basic reinforcement learning algorithms. (Apply)',
#     'Analyze the performance of reinforcement learning models in different environments. (Analyze)']},
#   {'topic': 'Evaluation and Optimization of Machine Learning Models',
#    'ilos': ['Describe different methods for evaluating machine learning models. (Understand)',
#     'Implement techniques for optimizing model performance. (Apply)',
#     'Evaluate and compare the effectiveness of different optimization techniques. (Evaluate)']}],
#  'references': [{'reference': 'Alpaydin, E. (2020). Introduction to machine learning.',
#    'link': 'https://books.google.com/books?hl=en&lr=&id=tZnSDwAAQBAJ&oi=fnd&pg=PR7&dq=Introduction+to+machine+learning+textbooks&ots=F4SW9WbpBe&sig=0mQG3DxbE1uUjCsJzw5aw1ht224'},
#   {'reference': 'Jiang, H. (2021). Machine learning fundamentals: A concise introduction.',
#    'link': 'https://books.google.com/books?hl=en&lr=&id=L2dNEAAAQBAJ&oi=fnd&pg=PP1&dq=Introduction+to+machine+learning+textbooks&ots=UqzQ4-LkGj&sig=QjvVE42JfTVhqpE46noDYNWudbE'},
#   {'reference': 'Jo, T. (2021). Machine Learning Foundations.',
#    'link': 'https://link.springer.com/content/pdf/10.1007/978-3-030-65900-4.pdf'},
#   {'reference': 'Raschka, S., Liu, Y. H., Mirjalili, V., & Dzhulgakov, D. (2022). Machine Learning with PyTorch and Scikit-Learn: Develop machine learning and deep learning models with Python.',
#    'link': 'https://books.google.com/books?hl=en&lr=&id=SVxaEAAAQBAJ&oi=fnd&pg=PP1&dq=Evaluation+and+optimization+of+machine+learning+models+academic+books&ots=1duOyMxzjd&sig=21QZLijO9WVKWt2Sl1jqKr-oLDw'},
#   {'reference': 'Goldberg, Y. (2022). Neural network methods for natural language processing.',
#    'link': 'https://books.google.com/books?hl=en&lr=&id=64hyEAAAQBAJ&oi=fnd&pg=PP1&dq=Deep+learning,+reinforcement+learning,+and+natural+language+processing+textbooks&ots=t8EcAJx7aC&sig=MSwmZLQVZcWFNLAENKJOlzyKm1o'}],
#  'activities': [{'week': 'Week 1',
#    'topic': 'Introduction to Machine Learning',
#    'activity_description': 'Lecture on the basic concepts and history of machine learning, followed by a discussion on different types of learning (supervised, unsupervised, and reinforcement learning).',
#    'expected_output': 'Short essay on the history and types of machine learning.',
#    'assessment_tools': 'Rubric for essay evaluation.'},
#   {'week': 'Week 2',
#    'topic': 'Introduction to Machine Learning',
#    'activity_description': 'Group discussion on various real-world applications of machine learning. Students will present case studies.',
#    'expected_output': 'Group presentation and report on real-world applications.',
#    'assessment_tools': 'Presentation rubric and report assessment criteria.'},
#   {'week': 'Week 3',
#    'topic': 'Machine Learning Fundamentals',
#    'activity_description': 'Lecture on the principles of regression and classification, followed by hands-on implementation of basic algorithms using Python.',
#    'expected_output': 'Implementation of a simple regression and classification algorithm.',
#    'assessment_tools': 'Code review and performance evaluation.'},
#   {'week': 'Week 4',
#    'topic': 'Machine Learning Fundamentals',
#    'activity_description': 'Lecture on clustering and dimensionality reduction techniques, followed by practical exercises.',
#    'expected_output': 'Implementation of clustering and dimensionality reduction algorithms.',
#    'assessment_tools': 'Code review and performance evaluation.'},
#   {'week': 'Week 5',
#    'topic': 'Decision Trees and Random Forests',
#    'activity_description': 'Lecture on decision tree algorithms, followed by hands-on exercises to implement decision trees for classification tasks.',
#    'expected_output': 'Implementation of a decision tree algorithm.',
#    'assessment_tools': 'Code review and performance evaluation.'},
#   {'week': 'Week 6',
#    'topic': 'Decision Trees and Random Forests',
#    'activity_description': 'Lecture on random forests, followed by practical exercises.',
#    'expected_output': 'Implementation of a random forest algorithm.',
#    'assessment_tools': 'Code review and performance evaluation.'},
#   {'week': 'Week 7',
#    'topic': 'Decision Trees and Random Forests',
#    'activity_description': 'Lecture on performance evaluation techniques, followed by exercises to evaluate decision trees and random forests.',
#    'expected_output': 'Performance evaluation report.',
#    'assessment_tools': 'Report assessment criteria.'},
#   {'week': 'Week 8',
#    'topic': 'Support Vector Machines',
#    'activity_description': 'Lecture on the theory behind SVMs, followed by practical exercises to implement SVMs for classification tasks.',
#    'expected_output': 'Implementation of an SVM algorithm.',
#    'assessment_tools': 'Code review and performance evaluation.'},
#   {'week': 'Week 9',
#    'topic': 'Support Vector Machines',
#    'activity_description': 'Lecture on performance analysis techniques, followed by exercises to analyze the performance of SVMs on different datasets.',
#    'expected_output': 'Performance analysis report.',
#    'assessment_tools': 'Report assessment criteria.'},
#   {'week': 'Week 10',
#    'topic': 'Neural Networks and Deep Learning',
#    'activity_description': 'Lecture on the basic structure and functioning of neural networks, followed by practical exercises.',
#    'expected_output': 'Implementation of a simple neural network.',
#    'assessment_tools': 'Code review and performance evaluation.'},
#   {'week': 'Week 11',
#    'topic': 'Neural Networks and Deep Learning',
#    'activity_description': 'Introduction to deep learning frameworks such as TensorFlow and PyTorch, followed by hands-on exercises.',
#    'expected_output': 'Implementation of a neural network using a deep learning framework.',
#    'assessment_tools': 'Code review and performance evaluation.'},
#   {'week': 'Week 12',
#    'topic': 'Neural Networks and Deep Learning',
#    'activity_description': 'Lecture on advanced neural network architectures, followed by practical exercises.',
#    'expected_output': 'Implementation of an advanced neural network (e.g., CNN, RNN).',
#    'assessment_tools': 'Code review and performance evaluation.'},
#   {'week': 'Week 13',
#    'topic': 'Natural Language Processing (NLP)',
#    'activity_description': 'Lecture on key concepts of NLP and its applications, followed by practical exercises.',
#    'expected_output': 'Implementation of a basic NLP task (e.g., text classification).',
#    'assessment_tools': 'Code review and performance evaluation.'},
#   {'week': 'Week 14',
#    'topic': 'Natural Language Processing (NLP)',
#    'activity_description': 'Lecture on advanced NLP techniques, followed by hands-on exercises.',
#    'expected_output': 'Implementation of an advanced NLP task (e.g., sentiment analysis).',
#    'assessment_tools': 'Code review and performance evaluation.'},
#   {'week': 'Week 15',
#    'topic': 'Reinforcement Learning',
#    'activity_description': 'Lecture on the principles of reinforcement learning, followed by practical exercises.',
#    'expected_output': 'Implementation of a basic reinforcement learning algorithm.',
#    'assessment_tools': 'Code review and performance evaluation.'},
#   {'week': 'Week 16',
#    'topic': 'Reinforcement Learning',
#    'activity_description': 'Lecture on advanced reinforcement learning techniques, followed by hands-on exercises.',
#    'expected_output': 'Implementation of an advanced reinforcement learning algorithm.',
#    'assessment_tools': 'Code review and performance evaluation.'},
#   {'week': 'Week 17',
#    'topic': 'Evaluation and Optimization of Machine Learning Models',
#    'activity_description': 'Lecture on evaluation and optimization techniques, followed by practical exercises.',
#    'expected_output': 'Implementation of model evaluation and optimization techniques.',
#    'assessment_tools': 'Code review and performance evaluation.'},
#   {'week': 'Week 18',
#    'topic': 'Course Wrap-Up',
#    'activity_description': 'Students will present their final projects, showcasing their ability to apply machine learning techniques to solve real-world problems.',
#    'expected_output': 'Final project presentation and report.',
#    'assessment_tools': 'Presentation rubric and report assessment criteria.'}]}

# %%
# Generate topics and search queries for each topic
def generate_queries(course_details, number_of_topics=5):
    prompt = f""" You are a capable and experienced researcher and professional educator. Provided are details regarding a course outline for which we need to look for references. 
Figure out the topics that are relevant to this course and generate queries to search for academic resources on Google Scholar.
    - For the arrangement of the topics, make sure the flow is appropriate for the course i.e. beginning with a general topic or overview and then moving on to more specific topics.
For each topic, you'll need to generate a separate query to look for potential academic resources to be used as reference materials for this course.
Generate a total of {number_of_topics} queries for the same number of topics to search in Google Scholar.
Output only the queries in the following json format:
{{
    "queries": [
        {{
            "topic": "topic 1",
            "query": "query 1"
        }},
        {{
            "topic": "topic 2",
            "query": "query 2"
        }}...
    ]
}}

Course Details:
{course_details}
"""
    
    queries = gpt_response(prompt,'gpt-4-1106-preview',response_format='json_object')
    return queries

# %%
queries = generate_queries(course_details,5)
print(queries)
queries_json = json.loads(queries)
# Out:
# {
#     "queries": [
#         {
#             "topic": "Overview of Information Technology",
#             "query": "historical development of information technology"
#         },
#         {
#             "topic": "Information Technology and Society",
#             "query": "impact of information technology on society"
#         },
#         {
#             "topic": "Information Technology in the Philippines",
#             "query": "development of information technology in the Philippines"
#         },
#         {
#             "topic": "Ethical Issues in Information Technology",
#             "query": "ethical considerations in information technology"
#         },
#         {
#             "topic": "Information Technology and Human Relationships",
#             "query": "effects of information technology on human relationships"
#         }
#     ]
# }

# %%
# Input search queries to search in Google Scholar
def search_google_scholar(query, num_results=3,language = 'en',as_ylo = 2020):
    """
    Params:
    query (str): The search query
    num_results (int): Number of results to return
    language (str): Two-letter code for desired language (i.e. "en" for English, "tl" for Tagalog/Filipino)
    as_ylo (int): The year of the last publication to be returned
    """
    
    # Your SerpAPI key
    api_key = "54dace100f45fd1e2deb96294960500abe400723302dc6959857888d013fd25a"

    # Set up the search parameters
    params = {
        "engine": "google_scholar",
        "q": query,  # Your search query
        "api_key": api_key,
        "as_ylo": as_ylo,
        "hl":language,
        'num': num_results
    }

    # Make the API request
    response = requests.get("https://serpapi.com/search", params=params)

    # Check if the request was successful
    if response.status_code == 200:
        # Parse the JSON response
        results = response.json()
        return results
    else:
        print("Failed to retrieve data:", response.status_code)
        return None

# %%
# For each query, get the top 1 result from Google Scholar and combine into a single string
total_search_results = ""
for query in queries_json['queries']:
    results = search_google_scholar(query['query'],3)
    temp_result =f"Topic: {query['topic']}\nResults:\n"
    for search_results in results['organic_results']:
        temp_result += f"""
        Title: {search_results['title']}
        Link: {search_results['link']}
        Snippet: {search_results['snippet']}
        Publication Summary: {search_results['publication_info']['summary']}

"""
    total_search_results += temp_result
print(total_search_results)
# Out:
# Topic: Overview of Information Technology
# Results:
#
#         Title: Computer: A history of the information machine
#         Link: https://books.google.com/books?hl=en&lr=&id=G868EAAAQBAJ&oi=fnd&pg=PT7&dq=historical+development+of+information+technology&ots=h7UG5FwuIr&sig=raNtd8bxnE7g032zwXPYV9tb1kk
#         Snippet: … history and globalization of information technology have been published in Technology and … take a broader view of the history of the computer as the history of the information machine. …
#         Publication Summary: M Campbell-Kelly, WF Aspray, JR Yost, H Tinn… - 2023 - books.google.com
#
#
#         Title: Application of modular teaching technology in technology
#         Link: https://cyberleninka.ru/article/n/application-of-modular-teaching-technology-in-technology
#         Snippet: … history of human history, choosing the necessary information … information and teaching the necessary information and to … technology, so the need to use modal education technology in …
#         Publication Summary: YEU Minamatov - Scientific progress, 2021 - cyberleninka.ru
#
#
#         Title: Towards Culture-Aware Smart and Sustainable Cities: Integrating Historical Sources in Spatial Information Infrastructures
#         Link: https://www.mdpi.com/2220-9964/10/9/588
#         Snippet: … -level functionality of producing historical data to be integrated in information infrastructures, as … This section identifies three key technologies to serve the above functions on information …
#         Publication Summary: B Bucher, C Hein, D Raines… - … Journal of Geo-Information, 2021 - mdpi.com
#
# Topic: Information Technology and Society
# Results:
#
#         Title: Impact of information technology innovation on firm performance in Kenya
#         Link: https://www.tandfonline.com/doi/abs/10.1080/02681102.2019.1573717
#         Snippet: … information technology innovation influences firm performance in Kenya given the low level of technology … This study addresses the following questions: Does information technology …
#         Publication Summary: SM Chege, D Wang, SL Suntu - Information Technology for …, 2020 - Taylor & Francis
#
#
#         Title: Information technology innovation and its impact on job creation by SMEs in developing countries: an analysis of the literature review
#         Link: https://www.tandfonline.com/doi/abs/10.1080/09537325.2019.1651263
#         Snippet: … The effective use of information technology in small businesses has a major impact on their … Thus, the need for the government to develop technology innovative strategies for small …
#         Publication Summary: SM Chege, D Wang - Technology Analysis & Strategic …, 2020 - Taylor & Francis
#
#
#         Title: The impact of information technologies on distance education during pandemic in the Republic of Uzbekistan
#         Link: https://mail.palarch.nl/index.php/jae/article/download/2362/2326
#         Snippet: … The specificity of distance education is its ability to meet the needs of the student, thanks to the mobile, virtual form of education, on the one hand, and on the other, the needs of society …
#         Publication Summary: E Salakhova, M Shamsitdinova… - PalArch's Journal of …, 2020 - mail.palarch.nl
#
# Topic: Information Technology in the Philippines
# Results:
#
#         Title: Employability tracer study of Information Technology Education graduates from a state university in the Philippines
#         Link: https://www.sciencedirect.com/science/article/pii/S2590291120300449
#         Snippet: … Another local study which is noteworthy is that of Balingbing (2014) because the respondents of her study were also BS in Information Technology graduates which are similar to the …
#         Publication Summary: AC Albina, LP Sumagaysay - Social Sciences & Humanities Open, 2020 - Elsevier
#
#
#         Title: Exploring the factors to green IT adoption of SMEs in the Philippines
#         Link: https://www.igi-global.com/chapter/exploring-the-factors-to-green-it-adoption-of-smes-in-the-philippines/245489
#         Snippet: … the traditional notion on the adoption of information technology. Therefore, by involving in GIT … to analyze the development of GIT adoption among SMEs and in the Philippines. Thus, it is …
#         Publication Summary: AA Hernandez - Start-Ups and SMEs: Concepts, Methodologies …, 2020 - igi-global.com
#
#
#         Title: The Status, Challenges & Opportunities of Education Service Industry in the Philippines
#         Link: https://papers.ssrn.com/sol3/papers.cfm?abstract_id=4426082
#         Snippet: … as a vital goal for the Philippine government's economic development. Skilled personnel are in high … Information technology, such as the use of online resources and courses, can give …
#         Publication Summary: L Macatangay - … Service Industry in the Philippines (April 15, 2023), 2023 - papers.ssrn.com
#
# Topic: Ethical Issues in Information Technology
# Results:
#
#         Title: Ethical considerations in artificial intelligence
#         Link: https://www.sciencedirect.com/science/article/pii/S0720048X19304188
#         Snippet: … As in the case of most disruptive technologies, assessment of and consensus on the possible ethical pitfalls lag. New AI applications and start-up companies seem to emerge daily. At …
#         Publication Summary: NM Safdar, JD Banja, CC Meltzer - European journal of radiology, 2020 - Elsevier
#
#
#         Title: Revisiting health information technology ethical, legal, and social issues and evaluation: telehealth/telemedicine and COVID-19
#         Link: https://www.sciencedirect.com/science/article/pii/S1386505620309382
#         Snippet: … additional considerations and then calls for learning from the experience by posing potential evaluation and assessment questions intended to make telehealth as effective and ethical …
#         Publication Summary: B Kaplan - International journal of medical informatics, 2020 - Elsevier
#
#
#         Title: Qualitative research: Ethical considerations
#         Link: https://link.springer.com/chapter/10.1007/978-3-030-30199-6_6
#         Snippet: … Advances in information technology have also led to an increasing number of people sharing highly personal information online, which could jeopardise their control of personal data […
#         Publication Summary: AM Pietilä, SM Nurmi, A Halkoaho… - The application of content …, 2020 - Springer
#
# Topic: Information Technology and Human Relationships
# Results:
#
#         Title: Revisiting health information technology ethical, legal, and social issues and evaluation: telehealth/telemedicine and COVID-19
#         Link: https://www.sciencedirect.com/science/article/pii/S1386505620309382
#         Snippet: … These, combined into an applied ethics approach that examines practice would address context-specific issues together with the situations and relations people and technologies co-…
#         Publication Summary: B Kaplan - International journal of medical informatics, 2020 - Elsevier
#
#
#         Title: Artificial intelligence, robotics, advanced technologies and human resource management: a systematic review
#         Link: https://www.tandfonline.com/doi/abs/10.1080/09585192.2020.1871398
#         Snippet: … advanced technologies, for which information technology is the backbone, and their impact … and in which contexts AI is more effective for building customer relationships. More …
#         Publication Summary: D Vrontis, M Christofi, V Pereira, S Tarba… - … Journal of Human …, 2022 - Taylor & Francis
#
#
#         Title: Influences of the industry 4.0 revolution on the human capital development and consumer behavior: A systematic review
#         Link: https://www.mdpi.com/2071-1050/12/10/4035
#         Snippet: … information technology to implement IoT by integrating engineering knowledge [16]. The effects … , it is noteworthy to modify the relation between human capital and ethnic capital, which …
#         Publication Summary: V Sima, IG Gheorghe, J Subić, D Nancu - Sustainability, 2020 - mdpi.com

# %%
# Generate Lesson Plan from aggregated search results

# First Step will be to Generate the lesson plan CLOs and ILOs
learning_outcomes_prompt = f'''You are a highly-capable researcher and professional educator. Provided below are course details for a course outline you will need to generate.

Course Details:
    {course_details}

You are tasked to generate the following for a course outline for this course:
    1 Course Learning Outcomes (CLOs)
    2 Topics/ Modules and Intended Learning Outcomes (ILOs)
        - each topic requires at least 2 ILOs
        - each topic should be marked by starting with "Topic #", and each ILO should be marked by starting with "ILO #"
        - add the source/s for each topic
    3 References (at least 1 reference per topic and in {citation_style} format)
        
Provided below are the search results for reference material from Google Scholar for suggested topics to cover in this course. 
You may decide which topics and search results to include in the final result. 
Do not include all search results in the final course outline, and do not add sources not included below.

{total_search_results}
'''

learning_outcomes = gpt_response(learning_outcomes_prompt,'gpt-4-1106-preview')
print(learning_outcomes)
# Out:
# ### Course Learning Outcomes (CLOs)
#
# 1. Understand the historical development of information technology and its global and national implications.
# 2. Analyze the impact of information technology on society, culture, and human relationships.
# 3. Evaluate the ethical considerations and challenges presented by the advancements in information technology.
# 4. Assess the influence of information technology on professional, personal, and social advancement.
# 5. Discuss the current trends and issues in information technology, particularly in the context of the Philippines.
#
# ### Topics/Modules and Intended Learning Outcomes (ILOs)
#
# **Topic 1: Overview of Information Technology**
# - **ILO 1**: Describe the evolution and historical milestones of information technology from prehistoric times to the present.
# - **ILO 2**: Explain the role of information technology in shaping global history and culture.
# - *Source*: Campbell-Kelly, M., Aspray, W. F., Yost, J. R., & Tinn, H. (2023). Computer: A history of the information machine. https://books.google.com/books?hl=en&lr=&id=G868EAAAQBAJ
#
# **Topic 2: Information Technology and Society**
# - **ILO 1**: Analyze the effects of information technology innovations on firm performance and job creation.
# - **ILO 2**: Discuss the impact of information technology on education and societal needs during the pandemic.
# - *Source*: Chege, S. M., Wang, D., & Suntu, S. L. (2020). Impact of information technology innovation on firm performance in Kenya. Information Technology for Development, 26(2), 317-342. https://www.tandfonline.com/doi/abs/10.1080/02681102.2019.1573717
#
# **Topic 3: Information Technology in the Philippines**
# - **ILO 1**: Examine the employability and career trajectories of Information Technology Education graduates in the Philippines.
# - **ILO 2**: Discuss the adoption and challenges of green IT practices among SMEs in the Philippines.
# - *Source*: Albina, A. C., & Sumagaysay, L. P. (2020). Employability tracer study of Information Technology Education graduates from a state university in the Philippines. Social Sciences & Humanities Open, 2(1), 100045. https://www.sciencedirect.com/science/article/pii/S2590291120300449
#
# **Topic 4: Ethical Issues in Information Technology**
# - **ILO 1**: Evaluate the ethical considerations and challenges posed by artificial intelligence and other disruptive technologies.
# - **ILO 2**: Discuss the ethical, legal, and social implications of health information technology, particularly in the context of telehealth during pandemics.
# - *Source*: Safdar, N. M., Banja, J. D., & Meltzer, C. C. (2020). Ethical considerations in artificial intelligence. European Journal of Radiology, 123, 108774. https://www.sciencedirect.com/science/article/pii/S0720048X19304188
#
# **Topic 5: Information Technology and Human Relationships**
# - **ILO 1**: Assess the influence of artificial intelligence and robotics on human resource management and customer relationships.
# - **ILO 2**: Analyze the effects of the industry 4.0 revolution on human capital development and consumer behavior.
# - *Source*: Vrontis, D., Christofi, M., Pereira, V., Tarba, S., & Thrassou, A. (2022). Artificial intelligence, robotics, advanced technologies and human resource management: a systematic review. The International Journal of Human Resource Management, 33(4), 781-807. https://www.tandfonline.com/doi/abs/10.1080/09585192.2020.1871398
#
# ### References
#
# Campbell-Kelly, M., Aspray, W. F., Yost, J. R., & Tinn, H. (2023). Computer: A history of the information machine. https://books.google.com/books?hl=en&lr=&id=G868EAAAQBAJ
#
# Chege, S. M., Wang, D., & Suntu, S. L. (2020). Impact of information technology innovation on firm performance in Kenya. Information Technology for Development, 26(2), 317-342. https://www.tandfonline.com/doi/abs/10.1080/02681102.2019.1573717
#
# Albina, A. C., & Sumagaysay, L. P. (2020). Employability tracer study of Information Technology Education graduates from a state university in the Philippines. Social Sciences & Humanities Open, 2(1), 100045. https://www.sciencedirect.com/science/article/pii/S2590291120300449
#
# Safdar, N. M., Banja, J. D., & Meltzer, C. C. (2020). Ethical considerations in artificial intelligence. European Journal of Radiology, 123, 108774. https://www.sciencedirect.com/science/article/pii/S0720048X19304188
#
# Vrontis, D., Christofi, M., Pereira, V., Tarba, S., & Thrassou, A. (2022). Artificial intelligence, robotics, advanced technologies and human resource management: a systematic review. The International Journal of Human Resource Management, 33(4), 781-807. https://www.tandfonline.com/doi/abs/10.1080/09585192.2020.1871398

# %%
# Check is JSON works too to generate activities for the lesson plan
activities_prompt_json = f'''You are a highly-capable researcher and professional educator. Provided below are course details for a course outline you will need to generate.

Course Details:
{course_details}
{learning_outcomes}

-------------------

From the provided learning outcomes, create weekly activities for the course. 
This course divided into {number_of_topics} topics with a total of {total_hours} hours for the whole semester divided into {weekly_hours} hours per week ({total_hours//weekly_hours} weeks in total).
You may stretch one topic over the course of multiple weeks or add topics not included in the learning outcomes
Each activity should have a week number, topic, activity description, expected output or assessment, and assessment tools.
Follow the json formatting below:

{{
    "course_title": "Course Title",
    "course_description": "Course Description",
    "instructor_name": "Instructor Name",
    "credit_units": "Credit Units",
    "total_hours": "Total Hours",
    "weekly_hours": "Weekly Hours",
    "clos": [
        "CLO 1",
        "CLO 2",
        "CLO 3"
    ],
    "topics": [
        {{
            "topic": "Topic 1",
            "ilos": [
                "ILO 1",
                "ILO 2"
            ]
        }},
        {{
            "topic": "Topic 2",
            "ilos": [
                "ILO 1",
                "ILO 2"
            ]
        }}...
    ],
    "references":[
        {{
            reference: "Reference 1"
            link: "Link 1"
        }}
    ]
    "activities": [
        {{
            "week": "Week 1",
            "topic": "Topic 1",
            "activity_description": "activity description 1",
            "expected_output": "expected output 1",
            "assessment_tools": "assessment tools 1"
        }},
        {{
            "week": "Week 2",
            "topic": "Topic 2",
            "activity_description": "activity description 2",
            "expected_output": "expected output 2",
            "assessment_tools": "assessment tools 2"
        }}...
    ]
}}
'''
activities_json = gpt_response(activities_prompt_json,'gpt-4-1106-preview', response_format='json_object')
print(activities_json)
# Out:
# {
#     "course_title": "IT031 LIVING IN THE IT ERA (Digital Technology)",
#     "course_description": "This course covers the science, culture and ethics in information technology, its influence on modern living and human relationships, and uses for personal, professional, and social advancement.",
#     "instructor_name": "Jun Albert Pardillo",
#     "credit_units": "3",
#     "total_hours": "54",
#     "weekly_hours": "3",
#     "clos": [
#         "Understand the historical development of information technology and its global and national implications.",
#         "Analyze the impact of information technology on society, culture, and human relationships.",
#         "Evaluate the ethical considerations and challenges presented by the advancements in information technology.",
#         "Assess the influence of information technology on professional, personal, and social advancement.",
#         "Discuss the current trends and issues in information technology, particularly in the context of the Philippines."
#     ],
#     "topics": [
#         {
#             "topic": "Overview of Information Technology",
#             "ilos": [
#                 "Describe the evolution and historical milestones of information technology from prehistoric times to the present.",
#                 "Explain the role of information technology in shaping global history and culture."
#             ]
#         },
#         {
#             "topic": "Information Technology and Society",
#             "ilos": [
#                 "Analyze the effects of information technology innovations on firm performance and job creation.",
#                 "Discuss the impact of information technology on education and societal needs during the pandemic."
#             ]
#         },
#         {
#             "topic": "Information Technology in the Philippines",
#             "ilos": [
#                 "Examine the employability and career trajectories of Information Technology Education graduates in the Philippines.",
#                 "Discuss the adoption and challenges of green IT practices among SMEs in the Philippines."
#             ]
#         },
#         {
#             "topic": "Ethical Issues in Information Technology",
#             "ilos": [
#                 "Evaluate the ethical considerations and challenges posed by artificial intelligence and other disruptive technologies.",
#                 "Discuss the ethical, legal, and social implications of health information technology, particularly in the context of telehealth during pandemics."
#             ]
#         },
#         {
#             "topic": "Information Technology and Human Relationships",
#             "ilos": [
#                 "Assess the influence of artificial intelligence and robotics on human resource management and customer relationships.",
#                 "Analyze the effects of the industry 4.0 revolution on human capital development and consumer behavior."
#             ]
#         }
#     ],
#     "references":[
#         {
#             "reference": "Campbell-Kelly, M., Aspray, W. F., Yost, J. R., & Tinn, H. (2023). Computer: A history of the information machine.",
#             "link": "https://books.google.com/books?hl=en&lr=&id=G868EAAAQBAJ"
#         },
#         {
#             "reference": "Chege, S. M., Wang, D., & Suntu, S. L. (2020). Impact of information technology innovation on firm performance in Kenya.",
#             "link": "https://www.tandfonline.com/doi/abs/10.1080/02681102.2019.1573717"
#         },
#         {
#             "reference": "Albina, A. C., & Sumagaysay, L. P. (2020). Employability tracer study of Information Technology Education graduates from a state university in the Philippines.",
#             "link": "https://www.sciencedirect.com/science/article/pii/S2590291120300449"
#         },
#         {
#             "reference": "Safdar, N. M., Banja, J. D., & Meltzer, C. C. (2020). Ethical considerations in artificial intelligence.",
#             "link": "https://www.sciencedirect.com/science/article/pii/S0720048X19304188"
#         },
#         {
#             "reference": "Vrontis, D., Christofi, M., Pereira, V., Tarba, S., & Thrassou, A. (2022). Artificial intelligence, robotics, advanced technologies and human resource management: a systematic review.",
#             "link": "https://www.tandfonline.com/doi/abs/10.1080/09585192.2020.1871398"
#         }
#     ],
#     "activities": [
#         {
#             "week": "Week 1",
#             "topic": "Overview of Information Technology",
#             "activity_description": "Introduction to the course and an overview of the syllabus, followed by a lecture on the prehistoric times to the early 20th century IT developments.",
#             "expected_output": "Students will create a timeline of significant IT milestones.",
#             "assessment_tools": "Timeline presentation and class participation"
#         },
#         {
#             "week": "Week 2",
#             "topic": "Overview of Information Technology",
#             "activity_description": "Continuation of the historical overview focusing on post-World War II to the present IT developments.",
#             "expected_output": "Students will write a short essay on the role of IT in a significant global event.",
#             "assessment_tools": "Essay submission and discussion"
#         },
#         {
#             "week": "Week 3",
#             "topic": "Information Technology and Society",
#             "activity_description": "Discussion on how IT innovations have impacted firm performance and job creation.",
#             "expected_output": "Group presentation on case studies of IT impact on specific businesses.",
#             "assessment_tools": "Presentation and peer evaluation"
#         },
#         {
#             "week": "Week 4",
#             "topic": "Information Technology and Society",
#             "activity_description": "Exploration of IT's role in education and societal needs during the pandemic.",
#             "expected_output": "Students will participate in a debate on the benefits and drawbacks of e-learning.",
#             "assessment_tools": "Debate performance and reflection paper"
#         },
#         {
#             "week": "Week 5",
#             "topic": "Information Technology in the Philippines",
#             "activity_description": "Investigation of the employability and career trajectories of IT graduates in the Philippines.",
#             "expected_output": "Students will conduct interviews with IT professionals and present their findings.",
#             "assessment_tools": "Interview report and presentation"
#         },
#         {
#             "week": "Week 6",
#             "topic": "Information Technology in the Philippines",
#             "activity_description": "Examination of green IT practices among SMEs in the Philippines.",
#             "expected_output": "Students will prepare a proposal for implementing green IT practices in a small business.",
#             "assessment_tools": "Proposal document and class discussion"
#         },
#         {
#             "week": "Week 7",
#             "topic": "Ethical Issues in Information Technology",
#             "activity_description": "Evaluation of ethical considerations in AI and disruptive technologies through a workshop.",
#             "expected_output": "Students will develop ethical guidelines for AI use in a chosen industry.",
#             "assessment_tools": "Workshop participation and guidelines document"
#         },
#         {
#             "week": "Week 8",
#             "topic": "Ethical Issues in Information Technology",
#             "activity_description": "Discussion on the ethical, legal, and social implications of health IT.",
#             "expected_output": "Students will create a case study analysis of telehealth services during pandemics.",
#             "assessment_tools": "Case study analysis and class presentation"
#         },
#         {
#             "week": "Week 9",
#             "topic": "Information Technology and Human Relationships",
#             "activity_description": "Assessment of AI's influence on HR management and customer relationships.",
#             "expected_output": "Role-playing exercise to simulate AI integration in HR scenarios.",
#             "assessment_tools": "Role-play demonstration and reflective journal"
#         },
#         {
#             "week": "Week 10",
#             "topic": "Information Technology and Human Relationships",
#             "activity_description": "Analysis of Industry 4.0's effects on human capital and consumer behavior.",
#             "expected_output": "Research paper on the implications of Industry 4.0 for a specific sector.",
#             "assessment_tools": "Research paper and peer review"
#         },
#         {
#             "week": "Week 11-18",
#             "topic": "Capstone Project",
#             "activity_description": "Students will work on a capstone project that encompasses all five topics, applying their knowledge to a real-world IT problem or scenario, with periodic check-ins and feedback sessions.",
#             "expected_output": "A comprehensive report and presentation on the capstone project.",
#             "assessment_tools": "Project report, presentation, and peer evaluation"
#         }
#     ]
# }

# %%
from docx import Document
from docx.shared import Inches
import json
from docx.shared import Pt
from docx.enum.text import WD_ALIGN_PARAGRAPH
from docx.enum.table import WD_ALIGN_VERTICAL
from docx.oxml import OxmlElement
from docx.oxml.ns import qn

def add_hyperlink(paragraph, url, text, color, underline):
    # Create a new Run object and add a hyperlink
    part = paragraph.part
    r_id = part.relate_to(url, 'http://schemas.openxmlformats.org/officeDocument/2006/relationships/hyperlink', is_external=True)

    hyperlink = OxmlElement('w:hyperlink')
    hyperlink.set(qn('r:id'), r_id)

    new_run = OxmlElement('w:r')
    rPr = OxmlElement('w:rPr')

    # Add underline and color to the hyperlink
    if underline:
        u = OxmlElement('w:u')
        u.set('val', 'single')
        rPr.append(u)

    color_elem = OxmlElement('w:color')
    color_elem.set('val', color)
    rPr.append(color_elem)

    new_run.append(rPr)
    new_run.text = text
    hyperlink.append(new_run)

    paragraph._p.append(hyperlink)

    return hyperlink

def set_cell_border(cell, **kwargs):
    """
    Set cell's border
    Usage: set_cell_border(
        cell,
        top={"sz": 0, "val": "single", "color": "#FF0000", "space": "0"},
        bottom={"sz": 0, "color": "#00FF00", "val": "single"},
        start={"sz": 24, "val": "dashed", "shadow": "true"},
        end={"sz": 0, "val": "dashed"},
    )
    """
    tc = cell._tc
    tcPr = tc.get_or_add_tcPr()

    # check for tag existnace, if none found, then create one
    if not hasattr(tcPr, 'tcBorders'):
        tcPr.tcBorders = OxmlElement('w:tcBorders')

    # list over all available tags
    for edge in ('start', 'top', 'end', 'bottom', 'insideH', 'insideV'):
        edge_data = kwargs.get(edge)
        if edge_data:
            tag = 'w:{}'.format(edge)

            # check for tag existnace, if none found, then create one
            if not hasattr(tcPr.tcBorders, tag):
                el = OxmlElement(tag)
                tcPr.tcBorders.append(el)
            else:
                el = tcPr.tcBorders.__getattr__(tag)

            # looks like order of attributes is important
            for key in ["sz", "val", "color", "space", "shadow"]:
                if key in edge_data:
                    el.set(key, str(edge_data[key]))

def create_word_document_from_json(json_data, title="Course_Outline.docx"):

    doc = Document()
    doc.add_heading('Course Outline', level=1)

    # Create a table for course details
    details_table = doc.add_table(rows=2, cols=2)

    # Set table style to enable borders
    details_table.style = 'Table Grid'

    # Add course details in two columns
    detail_keys = ["course_title", "instructor_name", "credit_units", "total_hours"]
    for i, key in enumerate(detail_keys):
        cell = details_table.cell(i // 2, i % 2)
        cell.vertical_alignment = WD_ALIGN_VERTICAL.TOP
        cell.text = f"{key.replace('_', ' ').capitalize()}: {json_data[key]}"
        # Make the detail name bold
        for paragraph in cell.paragraphs:
            paragraph.runs[0].font.bold = True

    # Add Course Description
    doc.add_heading("Course Description:", level=2)
    doc.add_paragraph(json_data["course_description"], style='BodyText')

    # Add Course Learning Outcomes (CLOs)
    doc.add_heading('Course Learning Outcomes (CLOs)', level=2)
    for i, clo in enumerate(json_data['clos'], 1):
        doc.add_paragraph(f"CLO {i}: {clo}", style='ListBullet')

    # Add Topics / Modules and Intended Learning Outcomes (ILOs)
    doc.add_heading('Topics / Modules and Intended Learning Outcomes', level=2)
    for topic in json_data['topics']:
        doc.add_paragraph(topic['topic'], style='ListNumber')
        for ilo in topic['ilos']:
            doc.add_paragraph(ilo, style='ListBullet2')

    
    # Add a table to the document
    doc.add_heading('Weekly Activities', level=2)
    table = doc.add_table(rows=1, cols=5)

    # Set table style to enable borders
    table.style = 'Table Grid'

    # Add headers to the table
    hdr_cells = table.rows[0].cells
    headers = ["Week No.", "Topic", "Activity Description", "Expected Output", "Assessment Tools"]
    for i, header in enumerate(headers):
        hdr_cells[i].text = header
        paragraph = hdr_cells[i].paragraphs[0]
        run = paragraph.runs
        run[0].font.bold = True
        run[0].font.size = Pt(12)
        paragraph.alignment = WD_ALIGN_PARAGRAPH.CENTER

        # Set column widths
        if header == "Week No.":
            hdr_cells[i].width = Inches(0.75)
        elif header == "Activity Description":
            hdr_cells[i].width = Inches(3)
        else:
            hdr_cells[i].width = Inches(1.5)

    # Add rows to the table from the JSON data
    for activity in json_data['activities']:
        row_cells = table.add_row().cells
        row_cells[0].text = activity['week']
        row_cells[1].text = activity['topic']
        row_cells[2].text = activity['activity_description']
        row_cells[3].text = activity['expected_output']
        row_cells[4].text = activity['assessment_tools']

        for cell in row_cells:
            set_cell_border(cell, top={"sz": 12, "val": "single"},
                            bottom={"sz": 12, "val": "single"},
                            start={"sz": 12, "val": "single"},
                            end={"sz": 12, "val": "single"})

            # Set font size for cells
            for paragraph in cell.paragraphs:
                for run in paragraph.runs:
                    run.font.size = Pt(10)
            
            # Set topic bold
            if cell == row_cells[1]:
                for paragraph in cell.paragraphs:
                    for run in paragraph.runs:
                        run.font.bold = True

    # Add References section
    if "references" in json_data:
        doc.add_heading('References', level=2)
        for reference in json_data['references']:
            # Add each reference with its link as plain text
            ref_paragraph = doc.add_paragraph(style='BodyText')
            ref_paragraph.add_run(reference['reference']).italic = True
            if 'link' in reference:
                ref_paragraph.add_run("\nLink: ")
                ref_paragraph.add_run(reference['link'])

    # Allow for titles containing .docx to still be saved as a word document ending in .docx instead of .docx.docx
    title = title.replace(".docx", "")
    doc.save(title+'.docx')

# %%
create_word_document_from_json(json.loads(activities_json))
